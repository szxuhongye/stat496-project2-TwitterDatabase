# %%
import pymysql
import json
import pandas as pd
tweets_data_path = './test-out.txt'
tweets_user = []
userid=[]
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        user=tweet["user"]
        Id=user["id"]
        if Id not in userid:
            userid.append(Id)
            tweets_user.append(user)
    except:
        continue

# %%
len(tweets_user)
# Out:
# 141568

# %%
data[0]
# Out:
# {'id': 1072967981603450881,
#  'id_str': '1072967981603450881',
#  'name': 'Xavien Orchard',
#  'screen_name': 'OrchardXavien',
#  'location': None,
#  'url': None,
#  'description': 'A nasty man, hustler and overall force of nature with some MGTOW leanings. \nhttp://cash.me/RalphDLake\nSC: t_beneloventk19.',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 206,
#  'friends_count': 304,
#  'listed_count': 0,
#  'favourites_count': 26905,
#  'statuses_count': 23007,
#  'created_at': 'Wed Dec 12 21:34:36 +0000 2018',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': '',
#  'profile_background_image_url_https': '',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1141523488458575873/Vn0WifZI_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1141523488458575873/Vn0WifZI_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1072967981603450881/1581343409',
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %%
data_df = pd.DataFrame(tweets_user)

# %%
data_df.head()
# Out:
#    contributors_enabled                      created_at  default_profile  \
# 0                 False  Wed Dec 12 21:34:36 +0000 2018             True
# 1                 False  Sun Jun 03 23:18:50 +0000 2018            False
# 2                 False  Fri Jul 27 23:26:31 +0000 2018             True
# 3                 False  Thu Jul 16 22:11:37 +0000 2009            False
# 4                 False  Fri Oct 07 18:44:08 +0000 2016            False
#
#    default_profile_image                                        description  \
# 0                  False  A nasty man, hustler and overall force of natu...
# 1                  False  ✨“Artist” Amateur ✨ |•| LG(B)T+ | Multi fandom...
# 2                  False  Bitcoin trading wars (Burda yazılanlar yatırım...
# 3                  False  Zoey // 23 // bi // she/they // I post my nsfw...
# 4                  False                                               None
#
#    favourites_count follow_request_sent  followers_count following  \
# 0             26905                None              206      None
# 1            106943                None              155      None
# 2              2107                None              826      None
# 3              1934                None              145      None
# 4              8861                None                9      None
#
#    friends_count  ...  profile_text_color  profile_use_background_image  \
# 0            304  ...              333333                          True
# 1            599  ...              000000                         False
# 2            296  ...              333333                          True
# 3            227  ...              B4D800                          True
# 4              2  ...              000000                         False
#
#   protected    screen_name statuses_count  time_zone translator_type  \
# 0     False  OrchardXavien          23007       None            none
# 1     False  TheBlueSkyCat          25425       None            none
# 2     False      KingofBtc           3265       None            none
# 3     False        Zoey_Jo           5328       None            none
# 4     False       pzgranet          11252       None            none
#
#                        url utc_offset verified
# 0                     None       None    False
# 1                     None       None    False
# 2                     None       None    False
# 3  http://203y.tumblr.com/       None    False
# 4                     None       None    False
#
# [5 rows x 39 columns]

# %%
len(data_df)
# Out:
# 141568

# %%
db = pymysql.connect(host='projectuser.cjnnbmy31uit.us-east-2.rds.amazonaws.com',
                     user='admin',
                     passwd='4ULstfSQwoIkWzDz3Qd6',
                     port=3306,
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
cursor=db.cursor()
sql = "CREATE DATABASE tweetuser"
cursor.execute(sql)
# Out:
# 1

# %%
db.close()

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("mysql+pymysql://admin:4ULstfSQwoIkWzDz3Qd6@projectuser.cjnnbmy31uit.us-east-2.rds.amazonaws.com:3306/tweetuser?charset=utf8mb4") 
data_df.to_sql(name = 'user',con = engine,if_exists = 'replace')
# Out:
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8\\xE2\\x80\\x9C...' for column 'description' at row 2")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xA0\\xE2\\x84...' for column 'name' at row 2")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1lanl...' for column 'description' at row 3")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\x9E' for column 'description' at row 4")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x93\\x89\\xF0\\x9D...' for column 'description' at row 6")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE1\\xB4\\xA1\\xE1\\xB4\\x87...' for column 'location' at row 6")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x90\\x9A\\xF0\\x9D...' for column 'name' at row 6")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xBC n...' for column 'name' at row 8")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\x9Fe be...' for column 'description' at row 9")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0O-di...' for column 'name' at row 9")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA6\\x80\\xF0\\x9F...' for column 'description' at row 10")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA6\\x8B' for column 'name' at row 10")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\x9E A...' for column 'description' at row 11")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\xA0' for column 'description' at row 14")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xB2\\xF0\\x9F...' for column 'name' at row 16")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE8\\xB5\\xA4\\xE8\\xA5\\xBF...' for column 'description' at row 21")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\xA0\\x80\\xE2\\xA0\\x80...' for column 'description' at row 23")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE1\\x83\\xA6\\xE1\\x83\\xA6...' for column 'location' at row 23")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x93\\x9A\\xF0\\x9D...' for column 'name' at row 23")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\xA1' for column 'name' at row 25")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA6\\x88 |...' for column 'name' at row 27")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x93\\x9A  ...' for column 'description' at row 30")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x98\\x94\\xF0\\x9F...' for column 'description' at row 32")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x82\\xA2\\xE3\\x83\\xAA...' for column 'name' at row 32")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA9\\xF0\\x9F...' for column 'description' at row 34")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xB8 L...' for column 'name' at row 34")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x81\\xF0\\x9F...' for column 'name' at row 40")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x94' for column 'description' at row 44")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x93' for column 'name' at row 45")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9D\\xA4' for column 'description' at row 46")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x9F\\xF0\\x9F...' for column 'name' at row 47")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xB5\\xF0\\x9F...' for column 'description' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA6\\x8A (...' for column 'name' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x95\\xB8' for column 'name' at row 50")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x82\\xBF\\xE3\\x83\\x9E...' for column 'description' at row 55")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE7\\xA7\\x81\\xE3\\x81\\xAE...' for column 'location' at row 55")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x83\\xAB\\xE3\\x83\\xBC...' for column 'name' at row 55")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE6\\x9D\\xB1\\xE4\\xBA\\xAC...' for column 'description' at row 56")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA5\\xB0' for column 'description' at row 58")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC9\\x90\\xC9\\xA5\\xC9\\x94...' for column 'name' at row 58")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8F\\xB3\\xEF\\xB8...' for column 'description' at row 59")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x99 1...' for column 'location' at row 59")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\x82 I ...' for column 'description' at row 60")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x83\\x88\\xE3\\x82\\xA4...' for column 'name' at row 60")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x93\\xB8: ...' for column 'description' at row 61")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x95\\x9A\\xF0\\x9D...' for column 'name' at row 63")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x99\\x8F#s...' for column 'description' at row 66")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\x9D\\xEC\\xA7\\x84' for column 'name' at row 68")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA7\\xF0\\x9F...' for column 'description' at row 69")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x8E\\xF0\\x9F...' for column 'name' at row 69")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x81\\xB7\\xF0\\x9F\\x92...' for column 'name' at row 73")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\x8C\\xEF\\xB8\\x8F...' for column 'description' at row 74")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\x8A\\xE7\\xB5\\xB5...' for column 'description' at row 76")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x83\\x9E\\xE3\\x83\\xA1...' for column 'name' at row 76")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xAC\\xF0\\x9F...' for column 'description' at row 77")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x81\\xB6\\xE2\\x82\\x86...' for column 'name' at row 77")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x8D\\xF0\\x9F...' for column 'description' at row 86")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE8\\x89\\xAF\\xE3\\x81\\x84...' for column 'description' at row 87")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\xB4\\xE3\\x81\\x8B...' for column 'name' at row 87")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\xAD\\x90\\xEF\\xB8\\x8F...' for column 'name' at row 89")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE6\\xAD\\xA6\\xE6\\xB1\\x89...' for column 'location' at row 90")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\x80\\xEF\\xB8\\x8F...' for column 'description' at row 91")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x96 K...' for column 'name' at row 91")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xCB\\x97\\xCB\\x8F\\xCB\\x8B...' for column 'name' at row 93")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x8A' for column 'description' at row 3")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x83' for column 'description' at row 4")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1r, T...' for column 'location' at row 4")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEA\\xB9\\x80\\xED\\x83\\x9C...' for column 'description' at row 6")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xED\\x82\\xB4\\xEB\\xB2\\xA8...' for column 'name' at row 6")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x98\\x98\\xF0\\x9F...' for column 'description' at row 9")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0zmir' for column 'location' at row 13")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1' for column 'name' at row 15")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\xA1 @l...' for column 'description' at row 16")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x99\\x86\\xF0\\x9D...' for column 'name' at row 19")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD0\\x9F\\xD0\\xB5\\xD1\\x80...' for column 'description' at row 20")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD0\\x9F\\xD0\\xB5\\xD1\\x80...' for column 'location' at row 20")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD0\\x90\\xD0\\x9D \\xD0...' for column 'name' at row 20")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8E\\xA8\\xE5\\x89...' for column 'description' at row 22")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\x93\\xE3\\x81\\xAE...' for column 'location' at row 22")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x83\\xB1\\xE3\\x83\\xB3...' for column 'name' at row 22")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xBA\\xE2\\x9C...' for column 'description' at row 24")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9A\\xAA\\xEF\\xB8\\x8F' for column 'name' at row 26")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC5\\x9E R A' for column 'name' at row 27")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x96  ...' for column 'description' at row 32")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xAA\\xF0\\x9F...' for column 'name' at row 33")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x9FI'...' for column 'description' at row 37")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8' for column 'description' at row 40")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1l is...' for column 'description' at row 44")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\x9Flu' for column 'name' at row 44")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC5\\x9Fra' for column 'name' at row 45")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x80\\x80 \\xE2\\x8B...' for column 'description' at row 47")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE4\\xB8\\xA8it/...' for column 'location' at row 47")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xBF' for column 'name' at row 47")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA5\\xB6' for column 'description' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x9B\\x80\\xF0\\x9F...' for column 'location' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x91\\xBE' for column 'name' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x98\\x92 #...' for column 'description' at row 52")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x8A' for column 'name' at row 52")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8F\\xB3\\xEF\\xB8...' for column 'description' at row 55")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\x9Flar ...' for column 'description' at row 56")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0stan...' for column 'location' at row 56")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0NEM ...' for column 'name' at row 56")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD9\\x8B   ' for column 'location' at row 57")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD9\\x8B' for column 'name' at row 57")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9D\\xA4\\xEF\\xB8\\x8F...' for column 'description' at row 59")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xB5\\xF0\\x9F...' for column 'description' at row 62")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x91\\xBD\\x0AS...' for column 'description' at row 63")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x99\\x8F\\xF0\\x9F...' for column 'description' at row 64")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE5\\x9F\\xBA\\xE6\\x9C\\xAC...' for column 'description' at row 66")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA6\\x84\\xE2\\x9A...' for column 'location' at row 66")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1f Y\\xC4...' for column 'name' at row 70")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA6\\x81 C...' for column 'name' at row 71")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\x8D \\xE3\\x81...' for column 'description' at row 73")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\x8A\\xE5\\xAC\\xA2...' for column 'name' at row 73")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x80\\x90\\xE6\\x81\\xAF...' for column 'description' at row 75")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x99\\x87\\xE2\\x80...' for column 'location' at row 75")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\x82\\xE3\\x81\\x95...' for column 'name' at row 75")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x9B S...' for column 'description' at row 77")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\xAD\\x90\\xEF\\xB8\\x8F...' for column 'name' at row 78")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x88 P...' for column 'description' at row 79")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xBB' for column 'description' at row 80")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE5\\x91\\xBC\\xE7\\xA7\\xB0...' for column 'description' at row 82")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x82\\xA8\\xE3\\x83\\xB3...' for column 'name' at row 82")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xBA\\xF0\\x9F...' for column 'description' at row 83")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x95\\x8A\\xEF\\xB8...' for column 'name' at row 85")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x80Cr...' for column 'name' at row 87")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x9A\\xA8\\xF0\\x9F...' for column 'description' at row 88")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0zmir...' for column 'location' at row 92")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\x94 |...' for column 'description' at row 1")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xB5\\xF0\\x9F...' for column 'description' at row 3")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x88 1...' for column 'description' at row 5")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\xAA\\xF0\\x9F...' for column 'name' at row 5")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xCA\\x8E \\xC6\\x83\\xC9...' for column 'description' at row 7")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE1\\x9C\\x90\\xE1\\x9C\\x94...' for column 'name' at row 7")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x97\\xA3' for column 'description' at row 10")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xBC @...' for column 'description' at row 11")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA7\\xF0\\x9F...' for column 'description' at row 12")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x99\\x83 A...' for column 'description' at row 13")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD0\\x93k\\xC2\\xA3\\xC2...' for column 'description' at row 14")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1 \\xC3\\xA7\\xC2...' for column 'name' at row 14")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x98\\x8D\\xF0\\x9F...' for column 'description' at row 15")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x9E #...' for column 'name' at row 15")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\x98\\xF0\\x9F...' for column 'description' at row 18")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\xB8\\xB8 \\xE3\\x85...' for column 'description' at row 20")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9E\\xBB \\xF0\\x9D...' for column 'name' at row 20")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC5\\x9Eehin...' for column 'name' at row 21")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x91\\x8Bph...' for column 'description' at row 23")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA7\\xA2\\xF0\\x9F...' for column 'name' at row 23")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8X\\xF0\\x9F...' for column 'description' at row 26")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEC\\x88\\x98\\xEC\\xA0\\x95...' for column 'location' at row 26")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x88CA...' for column 'name' at row 26")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEF\\xA3\\xAB' for column 'name' at row 27")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9B\\xA4 He...' for column 'description' at row 28")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA9\\xF0\\x9F...' for column 'description' at row 30")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0st' for column 'location' at row 31")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\xA9' for column 'description' at row 33")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x8CRe...' for column 'location' at row 34")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x82\\xA2\\xE3\\x83\\x8B...' for column 'description' at row 40")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEF\\xBC\\x88\\xE3\\x82\\xA2...' for column 'name' at row 40")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\xB7\\xE2\\x80...' for column 'description' at row 41")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8E\\x93ed...' for column 'description' at row 42")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA8\\xF0\\x9F...' for column 'location' at row 43")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8\\xF0\\x9F\\x90...' for column 'name' at row 47")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x91\\xEB\\xB0...' for column 'description' at row 49")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xB8\\xEC\\x9E\\xA5...' for column 'location' at row 49")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEB\\xB0\\xB1\\xEC\\xBD\\x94...' for column 'name' at row 49")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x86\\x98 A...' for column 'description' at row 51")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xBA\\xF0\\x9F...' for column 'name' at row 53")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\x9C\\xEC\\x98\\x81...' for column 'description' at row 54")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x9A\\x93\\xE2\\x81...' for column 'name' at row 54")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE1\\xA5\\xB1ywo...' for column 'description' at row 58")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x97\\x98\\xF0\\x9D...' for column 'location' at row 58")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x91\\xBA\\xF0\\x9D...' for column 'name' at row 58")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x8D\\x9F\\xE2\\x9C\\xAA...' for column 'location' at row 60")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x90\\x8A\\xF0\\x9D...' for column 'name' at row 60")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x93\\xB8' for column 'description' at row 62")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x81\\xB7' for column 'name' at row 62")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x91\\xBC\\xF0\\x9D...' for column 'description' at row 63")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x91\\xBE\\xF0\\x9D...' for column 'name' at row 63")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA8\\xF0\\x9F...' for column 'description' at row 64")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE8\\xB6\\xA3\\xE5\\x91\\xB3...' for column 'description' at row 66")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x82\\xA2\\xE3\\x82\\xA4...' for column 'location' at row 66")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x95\\x8A*....' for column 'name' at row 66")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x88\\x80\\xEF\\xBD\\x80...' for column 'description' at row 68")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x88 |...' for column 'description' at row 69")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\x8D.' for column 'description' at row 71")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD1\\x94\\xE0\\xB8\\x97c...' for column 'name' at row 71")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x9F\\xF0\\x9F...' for column 'description' at row 75")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8\\xE2\\x8F\\xB3...' for column 'name' at row 75")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x9A\\x80| ...' for column 'description' at row 79")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\xA1' for column 'name' at row 79")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x93\\x8DSC...' for column 'description' at row 82")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xBB\\xF0\\x9F...' for column 'description' at row 2")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE5\\x86\\x99\\xE7\\x9C\\x9F...' for column 'description' at row 4")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x83\\xAA\\xE3\\x83\\xAA...' for column 'name' at row 4")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x91\\x93\\xF0\\x9D...' for column 'description' at row 7")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x92\\xBD\\xF0\\x9D...' for column 'name' at row 7")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA7\\xF0\\x9F...' for column 'location' at row 10")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x95\\xB8\\xF0\\x9D...' for column 'name' at row 10")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x93\\x9A' for column 'description' at row 11")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\x9FOP...' for column 'description' at row 14")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9D\\x84\\xE2\\x9D\\x84...' for column 'name' at row 14")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD8\\x8C \\xF0\\x9D\\x9F...' for column 'description' at row 15")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x9F\\xB9' for column 'location' at row 15")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD9\\x8Bemi' for column 'name' at row 15")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\x9B\\xF0\\x9D\\x92...' for column 'name' at row 16")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x93\\xA1\\xE2\\x93\\x9E...' for column 'name' at row 22")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA5\\xB0\\xF0\\x9F...' for column 'description' at row 24")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x96\\xF0\\x9F...' for column 'location' at row 24")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xB8' for column 'name' at row 24")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\x88\\xEF\\xB8\\x8F...' for column 'description' at row 26")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xA4\\x95\\xE0\\xA5\\x8B...' for column 'description' at row 28")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xB3\\xF0\\x9F...' for column 'name' at row 28")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x93\\xB2' for column 'description' at row 32")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD9\\x8B' for column 'name' at row 34")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x95\\x83\\xF0\\x9D...' for column 'name' at row 39")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\xAB' for column 'description' at row 40")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xB3' for column 'name' at row 40")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x95' for column 'description' at row 41")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x99 $...' for column 'description' at row 42")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x99' for column 'name' at row 42")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x80\\x8D\\xE3\\x85\\xA4...' for column 'description' at row 43")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x97 \\xE5...' for column 'name' at row 43")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\x8D\\xF0\\x9F...' for column 'location' at row 44")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x92\\x82\\xF0\\x9D...' for column 'name' at row 44")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8F\\xB3\\xEF\\xB8...' for column 'location' at row 45")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\x8E\\xEF\\xB8\\x8F...' for column 'description' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8\\xF0\\x9F\\x8C...' for column 'location' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x97\\xF0\\x9F...' for column 'name' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA9\\xF0\\x9F...' for column 'description' at row 51")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8   ...' for column 'description' at row 52")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x95' for column 'name' at row 52")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0\\xC5\\x9Fbi...' for column 'description' at row 54")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x98\\x8E\\xF0\\x9F...' for column 'description' at row 57")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8\\xF0\\x9F\\x92...' for column 'description' at row 59")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\xA1' for column 'location' at row 59")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x91\\xA8\\xF0\\x9F...' for column 'description' at row 61")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEF\\xA3\\xBF' for column 'name' at row 61")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8F\\x92\\xE2\\x9A...' for column 'description' at row 66")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x92\\xBF\\xF0\\x9D...' for column 'description' at row 69")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x96\\x9A\\xF0\\x9D...' for column 'name' at row 69")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE6\\x97\\xA5\\xE6\\x9C\\xAC...' for column 'description' at row 70")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xAF\\xF0\\x9F...' for column 'name' at row 70")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x91\\xB0 \\xF0...' for column 'description' at row 72")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x89' for column 'name' at row 72")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xA8\\xF0\\x9F...' for column 'description' at row 78")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x91\\x86' for column 'description' at row 79")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xCA\\x9C\\xE1\\xB4\\x87/...' for column 'location' at row 85")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x9A\\x96\\xF0\\x9D...' for column 'name' at row 85")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEF\\xB8\\x8F\\xE2\\x83\\xA3...' for column 'name' at row 86")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB8\\x84\\xE0\\xB8\\xB4...' for column 'description' at row 92")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB9\\x84\\xE0\\xB8\\xA1...' for column 'location' at row 92")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB8\\xAD\\xE0\\xB8\\xB6...' for column 'name' at row 92")
#   result = self._query(query)
# ...
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9A\\xBD\\xEF\\xB8\\x8F...' for column 'description' at row 41")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x9D' for column 'name' at row 42")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA3' for column 'location' at row 45")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x80' for column 'name' at row 45")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x95\\x91 18...' for column 'description' at row 46")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1 EYT...' for column 'name' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\xA5 A...' for column 'description' at row 49")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB8\\x9B\\xE0\\xB8\\xA5...' for column 'description' at row 50")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x81\\xB0\\xC2\\xB3\\xC2...' for column 'name' at row 50")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xAA\\x90' for column 'location' at row 52")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x91\\x91\\xF0\\x9D...' for column 'name' at row 52")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x86\\x91 \\xE3\\x81...' for column 'description' at row 53")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE7\\xBF\\x94\\xE3\\x81\\xA1...' for column 'location' at row 53")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE9\\x82\\xA3\\xE7\\xBF\\x94...' for column 'name' at row 53")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xAE\\x86\\xE0\\xAE\\xA3...' for column 'description' at row 54")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xB5' for column 'name' at row 60")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xAE\\xA8\\xE0\\xAE\\xAE...' for column 'description' at row 61")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x96\\xA0\\xE8\\x85\\x90...' for column 'description' at row 62")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\xB5\\xE3\\x81\\x98...' for column 'name' at row 62")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x8E' for column 'name' at row 65")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC5\\x84o!' for column 'description' at row 72")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x89\\xA0End...' for column 'description' at row 74")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\xA1\\x0ASh...' for column 'description' at row 1")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xB5\\xF0\\x9F...' for column 'location' at row 1")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE4\\xB8\\x80\\xE6\\x9C\\x9F...' for column 'name' at row 1")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1yoru...' for column 'description' at row 3")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\x9E\\x0A\\xE2...' for column 'description' at row 8")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x99\\xA1 ' for column 'location' at row 8")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x83 O...' for column 'name' at row 8")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB8\\x95\\xE0\\xB8\\xB4...' for column 'description' at row 9")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB8\\x84\\xE0\\xB8\\xB1...' for column 'name' at row 9")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x81\\xB7\\xE2\\x82\\x81...' for column 'name' at row 10")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\x94' for column 'description' at row 11")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9B\\x94\\xEF\\xB8\\x8F...' for column 'name' at row 13")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB9\\x80\\xE0\\xB8\\xAD...' for column 'description' at row 14")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x80\\x95' for column 'name' at row 14")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB0stan...' for column 'location' at row 17")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\x9Fuz H...' for column 'name' at row 17")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xA5\\x90 \\xE0\\xA4...' for column 'description' at row 22")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8Adu...' for column 'description' at row 24")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8The...' for column 'location' at row 24")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8DMC...' for column 'name' at row 24")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\xBC\\xE3\\x82\\x84...' for column 'description' at row 25")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\x86\\xE3\\x81\\xAA...' for column 'location' at row 25")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\xBB\\xE3\\x81\\x86...' for column 'name' at row 25")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xB1' for column 'name' at row 26")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x96\\xF0\\x9F...' for column 'description' at row 28")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x90\\xBE\\xF0\\x9D...' for column 'description' at row 30")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x9A\\x9D\\xF0\\x9D...' for column 'name' at row 30")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\xA3 G...' for column 'description' at row 31")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x90\\x8C\\xF0\\x9D...' for column 'name' at row 31")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB9\\x80\\xE0\\xB8\\xA1...' for column 'description' at row 33")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1sa' for column 'name' at row 34")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xBA\\xF0\\x9F...' for column 'name' at row 36")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x81\\x99\\xE3\\x81\\x84...' for column 'description' at row 37")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE5\\xA6\\x84\\xE6\\x83\\xB3...' for column 'location' at row 37")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE6\\xB0\\xB4\\xE6\\xB3\\xA2' for column 'name' at row 37")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x95\\xF0\\x9F...' for column 'description' at row 38")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x9D' for column 'name' at row 38")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x87\\xB2\\xF0\\x9F...' for column 'name' at row 40")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA5\\xB6' for column 'description' at row 41")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA5\\xB3' for column 'description' at row 42")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC5\\x9Fehir...' for column 'location' at row 42")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC5\\x9E' for column 'name' at row 42")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\xADTi...' for column 'description' at row 44")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xEA\\x92\\xB0\\xE2\\x99\\xA1...' for column 'name' at row 44")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE7\\xAB\\xB6\\xE9\\xA6\\xAC...' for column 'description' at row 46")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE6\\x9D\\xB1\\xE4\\xBA\\xAC...' for column 'location' at row 46")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x82\\x8A\\xE3\\x81\\x93...' for column 'name' at row 46")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\xA6\\x8B' for column 'name' at row 48")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\x9A\\xF0\\x9F...' for column 'description' at row 54")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x91\\x8B\\x0AW...' for column 'description' at row 58")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8D\\x9F' for column 'name' at row 58")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\xB6\\xF0\\x9F...' for column 'name' at row 59")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9D\\x98\\xB8\\xF0\\x9D...' for column 'description' at row 60")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x83\\x80\\xE3\\x83\\x8B...' for column 'name' at row 60")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x9A\\xABfa...' for column 'description' at row 65")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE4\\xB8\\x85\\xE1\\x96\\x87...' for column 'name' at row 65")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB8\\x95\\xE0\\xB8\\xB2...' for column 'description' at row 67")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE0\\xB9\\x83\\xE0\\xB8\\x84...' for column 'name' at row 67")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE5\\x85\\xA8\\xE9\\x83\\xBD...' for column 'description' at row 68")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE3\\x82\\x82\\xE3\\x81\\xA1...' for column 'name' at row 68")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x97\\x9F\\xCC\\xBD\\xE2...' for column 'name' at row 72")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x92\\xA1Pa...' for column 'description' at row 73")
#   result = self._query(query)

# %%
db = pymysql.connect(host='projectuser.cjnnbmy31uit.us-east-2.rds.amazonaws.com',
                     user='admin',
                     passwd='4ULstfSQwoIkWzDz3Qd6',
                     port=3306,
                     charset='utf8',
                     db='tweetuser',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
cursor=db.cursor()
sql = "select * from user"
cursor.execute(sql)
# Out:
# 141568

# %%
db.close()
