# %%
import pymysql
import json
import pandas as pd
tweets_user = []
userid=[]
with open('./data.txt') as f:
    data = json.loads(f.read())
for line in data:
    try:
        user=line["user"]
        Id=user["id"]
        if Id not in userid:
            userid.append(Id)
            tweets_user.append(user)
    except:
        continue

# %%
len(tweets_user)
# Out:
# 40888

# %%
tweets_user[0]
# Out:
# {'id': 1003415743491436544,
#  'id_str': '1003415743491436544',
#  'name': '🌠ℂ❆Տℳⅈℂ_ℂᗅͲ💫',
#  'screen_name': 'TheBlueSkyCat',
#  'location': None,
#  'url': None,
#  'description': '✨“Artist” Amateur ✨ |•| LG(B)T+ | Multi fandom ouh yeah |\nThe best big brother @Klerwin_ToyJoy✏️💙💕✨|•| 🇨🇱\nicon by: @Klerwin_ToyJoy',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 155,
#  'friends_count': 599,
#  'listed_count': 2,
#  'favourites_count': 106943,
#  'statuses_count': 25425,
#  'created_at': 'Sun Jun 03 23:18:50 +0000 2018',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
# ...

# %%
data_df = pd.DataFrame(tweets_user)

# %%
len(data_df)
# Out:
# 40888

# %%
db = pymysql.connect(host='projectuser.cjnnbmy31uit.us-east-2.rds.amazonaws.com',
                     user='admin',
                     passwd='4ULstfSQwoIkWzDz3Qd6',
                     port=3306,
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
cursor=db.cursor()
sql = "CREATE DATABASE tweetuser"
cursor.execute(sql)
# Out:
# 1

# %%
db.close()

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("mysql+pymysql://admin:4ULstfSQwoIkWzDz3Qd6@projectuser.cjnnbmy31uit.us-east-2.rds.amazonaws.com:3306/tweetuser?charset=utf8mb4") 
data_df.to_sql(name = 'user_info',con = engine,if_exists = 'replace')
# Out:
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE2\\x9C\\xA8\\xE2\\x80\\x9C...' for column 'description' at row 1")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xA0\\xE2\\x84...' for column 'name' at row 1")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xC4\\xB1lanl...' for column 'description' at row 2")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\x9E' for column 'description' at row 3")
#   result = self._query(query)
# D:\notebook\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x8C\\xBC n...' for column 'name' at row 4")
#   result = self._query(query)
# ...

# %%
db = pymysql.connect(host='projectuser.cjnnbmy31uit.us-east-2.rds.amazonaws.com',
                     user='admin',
                     passwd='4ULstfSQwoIkWzDz3Qd6',
                     port=3306,
                     charset='utf8',
                     db='tweetuser',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
cursor=db.cursor()
sql = "select * from user_info"
cursor.execute(sql)
# Out:
# 40888

# %%
db.close()
